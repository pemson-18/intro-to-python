# %% [markdown]
# <a href="https://colab.research.google.com/github/pemson-18/intro-to-python/blob/main/assignment-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Python — Assignment 2
#
# Short, focused tasks for Faculty (Math/Physics/Chemistry). Run each code cell and fill in answers where indicated.

# %% [markdown]
# ## Maths
#
# **1 — Plot quadratic functions**
#
# Task: Plot y = ax^2 + bx + c for (a,b,c) = (1,0,0), (1,-2,1), (-1,0,1) over x in [-10,10]. Add labels and legend.

# %%
# TODO: create numpy array x and plot three quadratics using matplotlib

# %% [markdown]
# **2 — Symbolic derivatives & integrals (SymPy)**
#
# Task: Using SymPy, compute derivative and indefinite integral of f(x)=x**3 - 3*x**2 + 2*x. Show simplified results.

# %%
# TODO: use sympy to differentiate and integrate

# %% [markdown]
# **3 — Matrix operations with NumPy**
#
# Task: Create matrices A = [[1,2],[3,4]] and B = [[2,0],[1,2]]. Compute A+B, A@B, determinant of A, and eigenvalues of A.

# %%
# TODO: create A,B and compute requested operations (use numpy.linalg for det and eig)

# %% [markdown]
# ## Physics
#
# **4 — Plot velocity vs time**
#
# Task: For a particle with v(t)=5 - 0.5*t (m/s), plot v from t=0..20 s and compute displacement by integrating v(t).

# %%
# TODO: plot v(t) and compute displacement (use numpy.trapz or analytic integration)

# %% [markdown]
# **5 — Simulate Simple Harmonic Motion (SHM)**
#
# Task: Simulate x(t)=A*cos(omega*t + phi) with A=1, omega=2*pi, phi=0, over 0..2 s. Plot x(t) and v(t) (numerical derivative).

# %%
# TODO: simulate SHM and plot position and velocity

# %% [markdown]
# **6 — Gravitational force arrays**
#
# Task: Given masses m1=5 kg and m2 array = [1,2,5,10] kg at distance r=2 m, compute gravitational force magnitudes using Newton's law (use G=6.67430e-11).

# %%
# TODO: compute force array using numpy

# %% [markdown]
# ----
#
# End of worksheet. Save your answers and compare with the solutions notebook.
